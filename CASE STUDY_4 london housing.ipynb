# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\Amina\Downloads\\file (4).csv")
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\Amina\AppData\Local\Temp\ipykernel_69104\1569058065.py:1: SyntaxWarning: invalid escape sequence '\A'
#   df=pd.read_csv("C:\\Users\Amina\Downloads\\file (4).csv")
#             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544   9/1/2019         england         249942  E92000001      64605.0
# 13545  10/1/2019         england         249376  E92000001      68677.0
# ...

# %%
df.head()
# Out:
#        date            area  average_price       code  houses_sold  \
# 0  1/1/1995  city of london          91449  E09000001         17.0
# 1  2/1/1995  city of london          82203  E09000001          7.0
# 2  3/1/1995  city of london          79121  E09000001         14.0
# 3  4/1/1995  city of london          77101  E09000001          7.0
# 4  5/1/1995  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
df.tail()
# Out:
#             date     area  average_price       code  houses_sold  no_of_crimes
# 13544   9/1/2019  england         249942  E92000001      64605.0           NaN
# 13545  10/1/2019  england         249376  E92000001      68677.0           NaN
# 13546  11/1/2019  england         248515  E92000001      67814.0           NaN
# 13547  12/1/2019  england         250410  E92000001          NaN           NaN
# 13548   1/1/2020  england         247355  E92000001          NaN           NaN

# %%
df.shape
# Out:
# (13549, 6)

# %%
df.info
# Out:
# <bound method DataFrame.info of             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544   9/1/2019         england         249942  E92000001      64605.0
# 13545  10/1/2019         england         249376  E92000001      68677.0
# 13546  11/1/2019         england         248515  E92000001      67814.0
# 13547  12/1/2019         england         250410  E92000001          NaN
# 13548   1/1/2020         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# ...

# %%
df.describe()
# Out:
#        average_price    houses_sold  no_of_crimes
# count   1.354900e+04   13455.000000   7439.000000
# mean    2.635197e+05    3893.994129   2158.352063
# std     1.876175e+05   12114.402476    902.087742
# min     4.072200e+04       2.000000      0.000000
# 25%     1.323800e+05     247.000000   1623.000000
# 50%     2.229190e+05     371.000000   2132.000000
# 75%     3.368430e+05    3146.000000   2582.000000
# max     1.463378e+06  132163.000000   7461.000000

# %%
df.describe().sum()
# Out:
# average_price    2.660928e+06
# houses_sold      1.653924e+05
# no_of_crimes     2.429744e+04
# dtype: float64

# %%
df.isnull()
# Out:
#         date   area  average_price   code  houses_sold  no_of_crimes
# 0      False  False          False  False        False          True
# 1      False  False          False  False        False          True
# 2      False  False          False  False        False          True
# 3      False  False          False  False        False          True
# 4      False  False          False  False        False          True
# ...      ...    ...            ...    ...          ...           ...
# 13544  False  False          False  False        False          True
# 13545  False  False          False  False        False          True
# 13546  False  False          False  False        False          True
# 13547  False  False          False  False         True          True
# 13548  False  False          False  False         True          True
#
# [13549 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# np.int64(0)

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13544    False
# 13545    False
# 13546    False
# 13547    False
# 13548    False
# Length: 13549, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['date', 'area', 'average_price', 'code', 'houses_sold', 'no_of_crimes'], dtype='object')

# %%
#1 Convert the datatype of date column to date-time format.

# %%
print(df.dtypes)
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# dtype: object

# %%
df["date"].dtype
# Out:
# dtype('O')

# %%
df["date"]
# Out:
# 0         1/1/1995
# 1         2/1/1995
# 2         3/1/1995
# 3         4/1/1995
# 4         5/1/1995
#            ...
# 13544     9/1/2019
# 13545    10/1/2019
# 13546    11/1/2019
# 13547    12/1/2019
# 13548     1/1/2020
# Name: date, Length: 13549, dtype: object

# %%
df["date"]=pd.to_datetime(df["date"])
print(df.dtypes)
# Out:
# date             datetime64[ns]
# area                     object
# average_price             int64
# code                     object
# houses_sold             float64
# no_of_crimes            float64
# dtype: object

# %%
df
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
# 2) a) Add a new column "year" in the dataframe,which contains years only.

# %%
df["year"]=df["date"].dt.year
df.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes  year
# 0           NaN  1995
# 1           NaN  1995
# 2           NaN  1995
# 3           NaN  1995
# 4           NaN  1995

# %%
df.insert(1,"month 1", df["date"].dt.month)
df
# Out:
#             date  month 1            area  average_price       code  \
# 0     1995-01-01        1  city of london          91449  E09000001
# 1     1995-02-01        2  city of london          82203  E09000001
# 2     1995-03-01        3  city of london          79121  E09000001
# 3     1995-04-01        4  city of london          77101  E09000001
# 4     1995-05-01        5  city of london          84409  E09000001
# ...          ...      ...             ...            ...        ...
# 13544 2019-09-01        9         england         249942  E92000001
# 13545 2019-10-01       10         england         249376  E92000001
# 13546 2019-11-01       11         england         248515  E92000001
# 13547 2019-12-01       12         england         250410  E92000001
# 13548 2020-01-01        1         england         247355  E92000001
#
#        houses_sold  no_of_crimes  year
# 0             17.0           NaN  1995
# 1              7.0           NaN  1995
# ...

# %%
df = df.drop(columns=["month 1"])
df
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  year
# 0               NaN  1995
# 1               NaN  1995
# ...

# %%
# 3)	Show all the recors where "no.of crimes" is 0. and ,how many such records are there?

# %%
df.groupby("no_of_crimes").get_group(0)
# Out:
#           date  month1            area  average_price       code  houses_sold  \
# 72  2001-01-01       1  city of london         284262  E09000001         24.0
# 73  2001-02-01       2  city of london         198137  E09000001         37.0
# 74  2001-03-01       3  city of london         189033  E09000001         44.0
# 75  2001-04-01       4  city of london         205494  E09000001         38.0
# 76  2001-05-01       5  city of london         223459  E09000001         30.0
# ..         ...     ...             ...            ...        ...          ...
# 178 2009-11-01      11  city of london         397909  E09000001         11.0
# 179 2009-12-01      12  city of london         411955  E09000001         16.0
# 180 2010-01-01       1  city of london         464436  E09000001         20.0
# 181 2010-02-01       2  city of london         490525  E09000001          9.0
# 182 2010-03-01       3  city of london         498241  E09000001         15.0
#
#      no_of_crimes  year  month
# ...

# %%
df.groupby("no_of_crimes").get_group(0).sum()
# Out:
# date-time        1/1/20012/1/20013/1/20014/1/20015/1/20016/1/20...
# area             city of londoncity of londoncity of londoncity...
# average_price                                             34286607
# code             E09000001E09000001E09000001E09000001E09000001E...
# houses_sold                                                 2649.0
# no_of_crimes                                                   0.0
# year             1/1/20012/1/20013/1/20014/1/20015/1/20016/1/20...
# dtype: object

# %%
df1=df.groupby("no_of_crimes").get_group(0)
df1
# Out:
#           date            area  average_price       code  houses_sold  \
# 72  2001-01-01  city of london         284262  E09000001         24.0
# 73  2001-02-01  city of london         198137  E09000001         37.0
# 74  2001-03-01  city of london         189033  E09000001         44.0
# 75  2001-04-01  city of london         205494  E09000001         38.0
# 76  2001-05-01  city of london         223459  E09000001         30.0
# ..         ...             ...            ...        ...          ...
# 178 2009-11-01  city of london         397909  E09000001         11.0
# 179 2009-12-01  city of london         411955  E09000001         16.0
# 180 2010-01-01  city of london         464436  E09000001         20.0
# 181 2010-02-01  city of london         490525  E09000001          9.0
# 182 2010-03-01  city of london         498241  E09000001         15.0
#
#      no_of_crimes
# 72            0.0
# 73            0.0
# 74            0.0
# 75            0.0
# 76            0.0
# ...

# %%
df1.sum()
# Out:
# date-time        1/1/20012/1/20013/1/20014/1/20015/1/20016/1/20...
# area             city of londoncity of londoncity of londoncity...
# average_price                                             34286607
# code             E09000001E09000001E09000001E09000001E09000001E...
# houses_sold                                                 2649.0
# no_of_crimes                                                   0.0
# year             1/1/20012/1/20013/1/20014/1/20015/1/20016/1/20...
# dtype: object

# %%
# 4)What is the maximum  "average_price" per year in england?

# %%
df2=df.groupby("area").get_group("england")
df2
# Out:
#             date     area  average_price       code  houses_sold  no_of_crimes
# 13248 1995-01-01  england          53203  E92000001      47639.0           NaN
# 13249 1995-02-01  england          53096  E92000001      47880.0           NaN
# 13250 1995-03-01  england          53201  E92000001      67025.0           NaN
# 13251 1995-04-01  england          53591  E92000001      56925.0           NaN
# 13252 1995-05-01  england          53678  E92000001      64192.0           NaN
# ...          ...      ...            ...        ...          ...           ...
# 13544 2019-09-01  england         249942  E92000001      64605.0           NaN
# 13545 2019-10-01  england         249376  E92000001      68677.0           NaN
# 13546 2019-11-01  england         248515  E92000001      67814.0           NaN
# 13547 2019-12-01  england         250410  E92000001          NaN           NaN
# 13548 2020-01-01  england         247355  E92000001          NaN           NaN
#
# [301 rows x 6 columns]

# %%
df2.groupby("area").max()
# Out:
#               date  average_price       code  houses_sold  no_of_crimes
# area
# england 2020-01-01         250410  E92000001     132163.0           NaN

# %%
# 5)	What is the  minimum no.of crimes recorded per area?

# %%
df
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
df["area"].nunique()
# Out:
# 45

# %%
df["area"].unique()
# Out:
# array(['city of london', 'barking and dagenham', 'barnet', 'bexley',
#        'brent', 'bromley', 'camden', 'croydon', 'ealing', 'enfield',
#        'tower hamlets', 'greenwich', 'hackney', 'south east',
#        'hammersmith and fulham', 'haringey', 'harrow', 'havering',
#        'hillingdon', 'hounslow', 'islington', 'kensington and chelsea',
#        'kingston upon thames', 'lambeth', 'lewisham', 'merton', 'newham',
#        'redbridge', 'richmond upon thames', 'southwark', 'sutton',
#        'waltham forest', 'wandsworth', 'westminster', 'inner london',
#        'outer london', 'north east', 'north west', 'yorks and the humber',
#        'east midlands', 'west midlands', 'east of england', 'london',
#        'south west', 'england'], dtype=object)

# %%
df.groupby("area").min()
# Out:
#                              date  average_price       code  houses_sold  \
# area
# barking and dagenham   1995-01-01          50460  E09000002         48.0
# barnet                 1995-01-01          90107  E09000003        139.0
# bexley                 1995-01-01          63723  E09000004         82.0
# brent                  1995-01-01          71307  E09000005         58.0
# bromley                1995-01-01          81124  E09000006        158.0
# camden                 1995-01-01         115419  E09000007         89.0
# city of london         1995-01-01          77101  E09000001          2.0
# croydon                1995-01-01          68006  E09000008        142.0
# ealing                 1995-01-01          79272  E09000009         96.0
# east midlands          1995-01-01          44506  E12000004       2245.0
# east of england        1995-01-01          55033  E12000006       3100.0
# enfield                1995-01-01          70631  E09000010         88.0
# ...

# %%
# 6)	a) Show the total count of records of each area,where average price is less than 100000.

# %%
df["average_price"].mean()
# Out:
# np.float64(263519.68433094694)

# %%
df[df["average_price"]<100000]
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13330 2001-11-01         england          95083  E92000001     109149.0
# 13331 2001-12-01         england          95992  E92000001      93329.0
# 13332 2002-01-01         england          96215  E92000001      71678.0
# 13333 2002-02-01         england          96676  E92000001      77131.0
# 13334 2002-03-01         england          98962  E92000001     102828.0
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
# b) show this result in visually only first six sample.(bar plot/pie chart)

# %%
c=df[df["average_price"]<100000]
c
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13330 2001-11-01         england          95083  E92000001     109149.0
# 13331 2001-12-01         england          95992  E92000001      93329.0
# 13332 2002-01-01         england          96215  E92000001      71678.0
# 13333 2002-02-01         england          96676  E92000001      77131.0
# 13334 2002-03-01         england          98962  E92000001     102828.0
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
sns.barplot(x="area",y="average_price",data=c)
# Out:
# <Axes: xlabel='area', ylabel='average_price'>
